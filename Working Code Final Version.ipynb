# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import wfdb
import os

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Define the path to the merged directory
merged_dir = '/Users/ekinyilmaz/Desktop/mentalab/merged_segments'

# Load the combined labels CSV file
combined_labels_csv_path = os.path.join(merged_dir, 'combined_segment_labels.csv')
combined_labels_df = pd.read_csv(combined_labels_csv_path)

# Function to plot segments with labels in a grid
def plot_segments_with_labels_grid(merged_dir, combined_labels_df):
    # Define channels to plot
    channels_to_plot = ['ECR', 'FCR', 'ECU', 'FCU']

    # Set the number of rows and columns in the grid
    num_rows = 15
    num_columns = 5

    # Set y-axis limits
    y_limits = (-800, 800)  # Adjust as needed based on your data

    # Create a subplot grid
    fig, axes = plt.subplots(num_rows, num_columns, figsize=(20, 30))

    # Iterate over segments in the combined labels DataFrame
    for index, row in combined_labels_df.iterrows():
        recording_name = row['Recording']
        segment_name = row['Segment']
        label = row['Label']

        # Load the segment CSV file
        segment_path = os.path.join(merged_dir, segment_name)
        segment_data = pd.read_csv(segment_path)

        # Plot each channel
        ax = axes[index // num_columns, index % num_columns]
        for channel in channels_to_plot:
            ax.plot(segment_data[channel], label=f'{channel} - {recording_name}')

        ax.set_title(f'Segment - {label} ({recording_name})')
        ax.set_xlabel('Sample Index')
        ax.set_ylabel('Filtered Signal Value')
        ax.legend()

        # Set y-axis limits for each subplot
        ax.set_ylim(y_limits)

    # Adjust layout to prevent clipping of subplot titles and labels
    plt.tight_layout()

    # Show the plots
    plt.show()

# Plot segments with labels in a grid
plot_segments_with_labels_grid(merged_dir, combined_labels_df)

# %%
# Define the path to the merged directory
merged_dir = '/Users/ekinyilmaz/Desktop/mentalab/merged_segments'

# Load the combined labels CSV file
combined_labels_csv_path = os.path.join(merged_dir, 'combined_segment_labels.csv')
combined_labels_df = pd.read_csv(combined_labels_csv_path)

# Define channels to select
channels_to_select = ['ECR', 'FCR', 'ECU', 'FCU']

# Define the order of movement numbers
movement_order = [1, 2, 3, 5, 7, 9, 11, 13, 15, 4, 6, 8, 10, 12, 14]

# Create a list to store dictionaries for each segment
segment_data_list = []

# Create a list to store dictionaries with file names, labels, and EMG arrays
data_for_csv = []

# Iterate over the specified order of movement numbers
for movement_number in movement_order:
    # Iterate over segments in the combined labels DataFrame
    for index, row in combined_labels_df.iterrows():
        recording_name = row['Recording']
        segment_name = row['Segment']
        label = row['Label']

        # Extract movement number from the segment name
        _, current_movement, _ = segment_name.split('_')
        current_movement = int(current_movement)

        # Check if the current segment matches the current movement number
        if current_movement == movement_number:
            # Load the segment CSV file
            segment_path = os.path.join(merged_dir, segment_name)
            segment_data = pd.read_csv(segment_path)

            # Select the relevant columns (ECR, FCR, ECU, FCU)
            selected_data = segment_data[channels_to_select]

            # Convert the selected data to a 2D array and append to the list
            emg_array = selected_data.to_numpy()

            # Store data in a dictionary along with label and file name
            segment_data_dict = {
                'File Name': segment_name,
                'Label': label,
                'EMG_Array': emg_array
            }

            segment_data_list.append(segment_data_dict)

            # Append data dictionary for writing to CSV
            data_for_csv.append(segment_data_dict)

# Example: Display labels, file names, and sizes
for segment_data_dict in segment_data_list:
    file_name = segment_data_dict['File Name']
    label = segment_data_dict['Label']
    emg_array = segment_data_dict['EMG_Array']
    
    print(f"File Name: {file_name}")
    print(f"Label: {label}")
    print(f"Size of EMG Array: {emg_array.shape}")
    print("\n")

# Example: Plot the 2D array for the first segment
plt.figure(figsize=(12, 6))
plt.imshow(segment_data_list[0]['EMG_Array'], aspect='auto', cmap='viridis')
plt.title(f'EMG Recording - Segment 1 - Label: {segment_data_list[0]["Label"]}')
plt.xlabel('Channel')
plt.ylabel('Sample Index')
plt.colorbar(label='Signal Value')
plt.show()

# Write file names, labels, and EMG arrays to a CSV file
csv_output_path = os.path.join(merged_dir, 'file_names_labels_and_arrays.csv')
csv_df = pd.DataFrame(data_for_csv)
csv_df.to_csv(csv_output_path, index=False)
# Out:
# File Name: segment_1_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_1_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_1_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_1_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_1_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_2_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_2_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_2_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_2_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_2_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_3_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_3_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_3_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_3_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_3_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_5_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_5_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_5_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_5_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_5_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_7_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_7_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_7_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_7_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_7_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_9_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_9_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_9_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_9_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_9_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_11_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_11_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_11_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_11_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_11_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_13_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_13_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_13_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_13_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_13_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_15_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_15_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_15_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_15_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_15_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_4_1.csv
# Label: wrist extension
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_4_2.csv
# Label: wrist extension
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_4_3.csv
# Label: wrist extension
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_4_4.csv
# Label: wrist extension
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_4_5.csv
# Label: wrist extension
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_6_1.csv
# Label: wrist flexion
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_6_2.csv
# Label: wrist flexion
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_6_3.csv
# Label: wrist flexion
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_6_4.csv
# Label: wrist flexion
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_6_5.csv
# Label: wrist flexion
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_8_1.csv
# Label: ulnar deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_8_2.csv
# Label: ulnar deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_8_3.csv
# Label: ulnar deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_8_4.csv
# Label: ulnar deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_8_5.csv
# Label: ulnar deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_10_1.csv
# Label: radial deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_10_2.csv
# Label: radial deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_10_3.csv
# Label: radial deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_10_4.csv
# Label: radial deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_10_5.csv
# Label: radial deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_12_1.csv
# Label: punch
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_12_2.csv
# Label: punch
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_12_3.csv
# Label: punch
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_12_4.csv
# Label: punch
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_12_5.csv
# Label: punch
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_14_1.csv
# Label: open hand
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_14_2.csv
# Label: open hand
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_14_3.csv
# Label: open hand
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_14_4.csv
# Label: open hand
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_14_5.csv
# Label: open hand
# Size of EMG Array: (3000, 4)

# %%
# Print the number of segments appended
print(f"Number of Segments Appended: {len(segment_data_list)}")

# Print the shape of each segment array
for segment_data_dict in segment_data_list:
    label = segment_data_dict['Label']
    emg_array = segment_data_dict['EMG_Array']
    print(f"Label: {label}, Shape of EMG Array: {emg_array.shape}")
# Out:
# Number of Segments Appended: 75
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: rest, Shape of EMG Array: (3000, 4)
# Label: wrist extension, Shape of EMG Array: (3000, 4)
# Label: wrist extension, Shape of EMG Array: (3000, 4)
# Label: wrist extension, Shape of EMG Array: (3000, 4)
# Label: wrist extension, Shape of EMG Array: (3000, 4)
# Label: wrist extension, Shape of EMG Array: (3000, 4)
# Label: wrist flexion, Shape of EMG Array: (3000, 4)
# Label: wrist flexion, Shape of EMG Array: (3000, 4)
# Label: wrist flexion, Shape of EMG Array: (3000, 4)
# Label: wrist flexion, Shape of EMG Array: (3000, 4)
# Label: wrist flexion, Shape of EMG Array: (3000, 4)
# Label: ulnar deviation, Shape of EMG Array: (3000, 4)
# Label: ulnar deviation, Shape of EMG Array: (3000, 4)
# Label: ulnar deviation, Shape of EMG Array: (3000, 4)
# Label: ulnar deviation, Shape of EMG Array: (3000, 4)
# Label: ulnar deviation, Shape of EMG Array: (3000, 4)
# Label: radial deviation, Shape of EMG Array: (3000, 4)
# Label: radial deviation, Shape of EMG Array: (3000, 4)
# Label: radial deviation, Shape of EMG Array: (3000, 4)
# Label: radial deviation, Shape of EMG Array: (3000, 4)
# Label: radial deviation, Shape of EMG Array: (3000, 4)
# Label: punch, Shape of EMG Array: (3000, 4)
# Label: punch, Shape of EMG Array: (3000, 4)
# Label: punch, Shape of EMG Array: (3000, 4)
# Label: punch, Shape of EMG Array: (3000, 4)
# Label: punch, Shape of EMG Array: (3000, 4)
# Label: open hand, Shape of EMG Array: (3000, 4)
# Label: open hand, Shape of EMG Array: (3000, 4)
# Label: open hand, Shape of EMG Array: (3000, 4)
# Label: open hand, Shape of EMG Array: (3000, 4)
# Label: open hand, Shape of EMG Array: (3000, 4)

# %%
len(segment_data_list)
# Out:
# 75

# %%
# Example: Display labels, file names, and sizes
for segment_data_dict in segment_data_list:
    file_name = segment_data_dict['File Name']
    label = segment_data_dict['Label']
    emg_array = segment_data_dict['EMG_Array']
    
    print(f"File Name: {file_name}")
    print(f"Label: {label}")
    print(f"Size of EMG Array: {emg_array.shape}")
    print("\n")

# Concatenate all EMG arrays along the sample index axis (axis=0)
concatenated_emg_array = np.vstack([segment_data_dict['EMG_Array'] for segment_data_dict in segment_data_list])

# Display the size of the concatenated EMG array
print(f"Size of Concatenated EMG Array: {concatenated_emg_array.shape}")

# Example: Plot the concatenated 2D array
plt.figure(figsize=(12, 6))
plt.imshow(concatenated_emg_array, aspect='auto', cmap='viridis')
plt.title(f'Concatenated EMG Recording - All Segments')
plt.xlabel('Channel')
plt.ylabel('Sample Index')
plt.colorbar(label='Signal Value')
plt.show()

# Write the concatenated EMG array to a CSV file
csv_output_path_concatenated = os.path.join(merged_dir, 'concatenated_arrays.csv')
pd.DataFrame(concatenated_emg_array).to_csv(csv_output_path_concatenated, index=False, header=False)
# Out:
# File Name: segment_1_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_1_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_1_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_1_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_1_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_2_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_2_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_2_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_2_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_2_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_3_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_3_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_3_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_3_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_3_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_5_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_5_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_5_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_5_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_5_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_7_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_7_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_7_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_7_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_7_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_9_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_9_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_9_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_9_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_9_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_11_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_11_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_11_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_11_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_11_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_13_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_13_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_13_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_13_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_13_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_15_1.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_15_2.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_15_3.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_15_4.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_15_5.csv
# Label: rest
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_4_1.csv
# Label: wrist extension
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_4_2.csv
# Label: wrist extension
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_4_3.csv
# Label: wrist extension
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_4_4.csv
# Label: wrist extension
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_4_5.csv
# Label: wrist extension
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_6_1.csv
# Label: wrist flexion
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_6_2.csv
# Label: wrist flexion
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_6_3.csv
# Label: wrist flexion
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_6_4.csv
# Label: wrist flexion
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_6_5.csv
# Label: wrist flexion
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_8_1.csv
# Label: ulnar deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_8_2.csv
# Label: ulnar deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_8_3.csv
# Label: ulnar deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_8_4.csv
# Label: ulnar deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_8_5.csv
# Label: ulnar deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_10_1.csv
# Label: radial deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_10_2.csv
# Label: radial deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_10_3.csv
# Label: radial deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_10_4.csv
# Label: radial deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_10_5.csv
# Label: radial deviation
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_12_1.csv
# Label: punch
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_12_2.csv
# Label: punch
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_12_3.csv
# Label: punch
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_12_4.csv
# Label: punch
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_12_5.csv
# Label: punch
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_14_1.csv
# Label: open hand
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_14_2.csv
# Label: open hand
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_14_3.csv
# Label: open hand
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_14_4.csv
# Label: open hand
# Size of EMG Array: (3000, 4)
#
#
# File Name: segment_14_5.csv
# Label: open hand
# Size of EMG Array: (3000, 4)
#
#
# Size of Concatenated EMG Array: (225000, 4)

# %%
# For most systems or networks it is not possible to make sense out of one single timestamp but rather over an interval of samples called windows.
# We want to generate windows of 128 samples out of the recordings and have a time overlap of 50% of each window.

# Write a function that extracts windows of the described shape from the dataset (use at least one subject).

def extract_windows(signals, window_size, overlap):
    """
    To extract windows from given EMG signals
    
    Inputs:
    - signals: 2D array, EMG signals (samples x channels)
    - window_size: int, size of each window samplewise
    - overlap: float, overlap ratio (0 no overlap 1 total overlap may create problem with zero division?? )

    Returns:
    - windows: 3D array, windows (num_windows x window_size x num_channels)
    """

    num_samples, num_channels = signals.shape
    print(f"num_samples:", {num_samples})
    print(f"num_channels:", {num_channels})
    
    step_size = int(round(window_size * (1 - overlap + 1e-100)))
    print(f"steps_size:", {step_size})
    
    num_windows = int((num_samples - window_size) / step_size) + 1 #len(sequence) - window_size + 1 to stop on window size
    print(f"num_windows:", {num_windows})
    
    windows = np.zeros((num_windows,window_size,num_channels)) #(num_matrix,row,col)
    print(f"windows' shape (num_windows x window_size x num_channels):", {windows.shape})
    
    #for i in range(0, num_windows*step_size, step_size):
        #windows[:, :, i] = signals[i:i+window_size, :]

    for i in range(num_windows):
        start = i * step_size #start = i * (step_size-1)
        end = start + window_size
        # Start and end indices shown
        print(f"Window {i + 1}: start={start}, end={end}")
        windows[i, :, :] = signals[start:end,]

    return windows

# Select and implement 14 features. Compute each feature for each EMG channels individually.

# signals: 2D array, EMG signals (samples x channels)
# windows: 3D array, extracted windows (num_windows x window_size x num_channels)
# transposed : 3D array, extracted windows (num_windows x num_channels x window_size)

from scipy.stats import skew, kurtosis
from scipy import stats, signal

# Extract features for single channel.
def extract_features(channel_data):
    # mean absolute value
    mean_abs_value = np.mean(np.abs(channel_data))
    
    # root means square
    rms_value = np.sqrt(np.mean(np.square(channel_data)))
    
    # waveform length
    waveform_length = np.sum(np.diff(channel_data))
    
    # integral absolute value
    integral_abs_value = np.sum(np.abs(channel_data))
    
    # skewness
    skewness_value = skew(channel_data)
    
    # variance
    variance = np.var(channel_data)
    
    # zero crossing
    
    # kurtosis
    kurtosis_value = kurtosis(channel_data)
    
    # energy
    energy = np.sum(channel_data ** 2)
    
    #  Difference Absolute Standard Deviation Value
    dasdv = np.sqrt(np.mean(np.square(np.diff(channel_data))))
    
    # log-detector
    #log_det = np.exp(np.mean(np.log(np.abs(channel_data))))
    
    # simple square integral
    ssi = np.sum(np.square(channel_data))

    freq, power = signal.periodogram(channel_data, 5120) #5120 is the number of points to use in the FFT.
    
    # mean power
    mean_power = np.mean(power, axis=0)
    
    # mean frequency
    mean_freq = np.sum(power*freq, axis=0) / np.sum(power, axis=0)
    
    #peak frequency
    peak_freq = freq[np.argmax(power, axis=0)]
    
    # power spectrum deformation
    def sm(order):
        return np.sum(power * np.power(freq, order), axis=0)
    ohm = np.sqrt(sm(2)/sm(0)) / (sm(1)/sm(0))
    
    return mean_abs_value, rms_value, integral_abs_value, variance, energy, dasdv, ssi, mean_power, kurtosis_value, skewness_value, mean_freq, peak_freq, waveform_length, ohm

# %%
emg_merged = concatenated_emg_array
windows = extract_windows(emg_merged, window_size = 300, overlap = 0.5) 
print(windows)
# Out:
# num_samples: {225000}
# num_channels: {4}
# steps_size: {150}
# num_windows: {1499}
# windows' shape (num_windows x window_size x num_channels): {(1499, 300, 4)}
# Window 1: start=0, end=300
# Window 2: start=150, end=450
# Window 3: start=300, end=600
# Window 4: start=450, end=750
# Window 5: start=600, end=900
# Window 6: start=750, end=1050
# Window 7: start=900, end=1200
# Window 8: start=1050, end=1350
# Window 9: start=1200, end=1500
# Window 10: start=1350, end=1650
# Window 11: start=1500, end=1800
# Window 12: start=1650, end=1950
# Window 13: start=1800, end=2100
# Window 14: start=1950, end=2250
# Window 15: start=2100, end=2400
# Window 16: start=2250, end=2550
# Window 17: start=2400, end=2700
# Window 18: start=2550, end=2850
# Window 19: start=2700, end=3000
# Window 20: start=2850, end=3150
# Window 21: start=3000, end=3300
# Window 22: start=3150, end=3450
# Window 23: start=3300, end=3600
# Window 24: start=3450, end=3750
# Window 25: start=3600, end=3900
# Window 26: start=3750, end=4050
# Window 27: start=3900, end=4200
# Window 28: start=4050, end=4350
# Window 29: start=4200, end=4500
# Window 30: start=4350, end=4650
# Window 31: start=4500, end=4800
# Window 32: start=4650, end=4950
# Window 33: start=4800, end=5100
# Window 34: start=4950, end=5250
# Window 35: start=5100, end=5400
# Window 36: start=5250, end=5550
# Window 37: start=5400, end=5700
# Window 38: start=5550, end=5850
# Window 39: start=5700, end=6000
# Window 40: start=5850, end=6150
# Window 41: start=6000, end=6300
# Window 42: start=6150, end=6450
# Window 43: start=6300, end=6600
# Window 44: start=6450, end=6750
# Window 45: start=6600, end=6900
# Window 46: start=6750, end=7050
# Window 47: start=6900, end=7200
# Window 48: start=7050, end=7350
# Window 49: start=7200, end=7500
# Window 50: start=7350, end=7650
# Window 51: start=7500, end=7800
# Window 52: start=7650, end=7950
# Window 53: start=7800, end=8100
# Window 54: start=7950, end=8250
# Window 55: start=8100, end=8400
# Window 56: start=8250, end=8550
# Window 57: start=8400, end=8700
# Window 58: start=8550, end=8850
# Window 59: start=8700, end=9000
# Window 60: start=8850, end=9150
# Window 61: start=9000, end=9300
# Window 62: start=9150, end=9450
# Window 63: start=9300, end=9600
# Window 64: start=9450, end=9750
# Window 65: start=9600, end=9900
# Window 66: start=9750, end=10050
# Window 67: start=9900, end=10200
# Window 68: start=10050, end=10350
# Window 69: start=10200, end=10500
# Window 70: start=10350, end=10650
# Window 71: start=10500, end=10800
# Window 72: start=10650, end=10950
# Window 73: start=10800, end=11100
# Window 74: start=10950, end=11250
# Window 75: start=11100, end=11400
# Window 76: start=11250, end=11550
# Window 77: start=11400, end=11700
# Window 78: start=11550, end=11850
# Window 79: start=11700, end=12000
# Window 80: start=11850, end=12150
# Window 81: start=12000, end=12300
# Window 82: start=12150, end=12450
# Window 83: start=12300, end=12600
# Window 84: start=12450, end=12750
# Window 85: start=12600, end=12900
# Window 86: start=12750, end=13050
# Window 87: start=12900, end=13200
# Window 88: start=13050, end=13350
# Window 89: start=13200, end=13500
# Window 90: start=13350, end=13650
# Window 91: start=13500, end=13800
# Window 92: start=13650, end=13950
# Window 93: start=13800, end=14100
# Window 94: start=13950, end=14250
# Window 95: start=14100, end=14400
# Window 96: start=14250, end=14550
# Window 97: start=14400, end=14700
# Window 98: start=14550, end=14850
# Window 99: start=14700, end=15000
# Window 100: start=14850, end=15150
# Window 101: start=15000, end=15300
# Window 102: start=15150, end=15450
# Window 103: start=15300, end=15600
# Window 104: start=15450, end=15750
# Window 105: start=15600, end=15900
# Window 106: start=15750, end=16050
# Window 107: start=15900, end=16200
# Window 108: start=16050, end=16350
# Window 109: start=16200, end=16500
# Window 110: start=16350, end=16650
# Window 111: start=16500, end=16800
# Window 112: start=16650, end=16950
# Window 113: start=16800, end=17100
# Window 114: start=16950, end=17250
# Window 115: start=17100, end=17400
# Window 116: start=17250, end=17550
# Window 117: start=17400, end=17700
# Window 118: start=17550, end=17850
# Window 119: start=17700, end=18000
# Window 120: start=17850, end=18150
# Window 121: start=18000, end=18300
# Window 122: start=18150, end=18450
# Window 123: start=18300, end=18600
# Window 124: start=18450, end=18750
# Window 125: start=18600, end=18900
# Window 126: start=18750, end=19050
# Window 127: start=18900, end=19200
# Window 128: start=19050, end=19350
# Window 129: start=19200, end=19500
# Window 130: start=19350, end=19650
# Window 131: start=19500, end=19800
# Window 132: start=19650, end=19950
# Window 133: start=19800, end=20100
# Window 134: start=19950, end=20250
# Window 135: start=20100, end=20400
# Window 136: start=20250, end=20550
# Window 137: start=20400, end=20700
# Window 138: start=20550, end=20850
# Window 139: start=20700, end=21000
# Window 140: start=20850, end=21150
# Window 141: start=21000, end=21300
# Window 142: start=21150, end=21450
# Window 143: start=21300, end=21600
# Window 144: start=21450, end=21750
# Window 145: start=21600, end=21900
# Window 146: start=21750, end=22050
# Window 147: start=21900, end=22200
# Window 148: start=22050, end=22350
# Window 149: start=22200, end=22500
# Window 150: start=22350, end=22650
# Window 151: start=22500, end=22800
# Window 152: start=22650, end=22950
# Window 153: start=22800, end=23100
# Window 154: start=22950, end=23250
# Window 155: start=23100, end=23400
# Window 156: start=23250, end=23550
# Window 157: start=23400, end=23700
# Window 158: start=23550, end=23850
# Window 159: start=23700, end=24000
# Window 160: start=23850, end=24150
# Window 161: start=24000, end=24300
# Window 162: start=24150, end=24450
# Window 163: start=24300, end=24600
# Window 164: start=24450, end=24750
# Window 165: start=24600, end=24900
# Window 166: start=24750, end=25050
# Window 167: start=24900, end=25200
# Window 168: start=25050, end=25350
# Window 169: start=25200, end=25500
# Window 170: start=25350, end=25650
# Window 171: start=25500, end=25800
# Window 172: start=25650, end=25950
# Window 173: start=25800, end=26100
# Window 174: start=25950, end=26250
# Window 175: start=26100, end=26400
# Window 176: start=26250, end=26550
# Window 177: start=26400, end=26700
# Window 178: start=26550, end=26850
# Window 179: start=26700, end=27000
# Window 180: start=26850, end=27150
# Window 181: start=27000, end=27300
# Window 182: start=27150, end=27450
# Window 183: start=27300, end=27600
# Window 184: start=27450, end=27750
# Window 185: start=27600, end=27900
# Window 186: start=27750, end=28050
# Window 187: start=27900, end=28200
# Window 188: start=28050, end=28350
# Window 189: start=28200, end=28500
# Window 190: start=28350, end=28650
# Window 191: start=28500, end=28800
# Window 192: start=28650, end=28950
# Window 193: start=28800, end=29100
# Window 194: start=28950, end=29250
# Window 195: start=29100, end=29400
# Window 196: start=29250, end=29550
# Window 197: start=29400, end=29700
# Window 198: start=29550, end=29850
# Window 199: start=29700, end=30000
# Window 200: start=29850, end=30150
# Window 201: start=30000, end=30300
# Window 202: start=30150, end=30450
# Window 203: start=30300, end=30600
# Window 204: start=30450, end=30750
# Window 205: start=30600, end=30900
# Window 206: start=30750, end=31050
# Window 207: start=30900, end=31200
# Window 208: start=31050, end=31350
# Window 209: start=31200, end=31500
# Window 210: start=31350, end=31650
# Window 211: start=31500, end=31800
# Window 212: start=31650, end=31950
# Window 213: start=31800, end=32100
# Window 214: start=31950, end=32250
# Window 215: start=32100, end=32400
# Window 216: start=32250, end=32550
# Window 217: start=32400, end=32700
# Window 218: start=32550, end=32850
# Window 219: start=32700, end=33000
# Window 220: start=32850, end=33150
# Window 221: start=33000, end=33300
# Window 222: start=33150, end=33450
# Window 223: start=33300, end=33600
# Window 224: start=33450, end=33750
# Window 225: start=33600, end=33900
# Window 226: start=33750, end=34050
# Window 227: start=33900, end=34200
# Window 228: start=34050, end=34350
# Window 229: start=34200, end=34500
# Window 230: start=34350, end=34650
# Window 231: start=34500, end=34800
# Window 232: start=34650, end=34950
# Window 233: start=34800, end=35100
# Window 234: start=34950, end=35250
# Window 235: start=35100, end=35400
# Window 236: start=35250, end=35550
# Window 237: start=35400, end=35700
# Window 238: start=35550, end=35850
# Window 239: start=35700, end=36000
# Window 240: start=35850, end=36150
# Window 241: start=36000, end=36300
# Window 242: start=36150, end=36450
# Window 243: start=36300, end=36600
# Window 244: start=36450, end=36750
# Window 245: start=36600, end=36900
# Window 246: start=36750, end=37050
# Window 247: start=36900, end=37200
# Window 248: start=37050, end=37350
# Window 249: start=37200, end=37500
# Window 250: start=37350, end=37650
# Window 251: start=37500, end=37800
# Window 252: start=37650, end=37950
# Window 253: start=37800, end=38100
# Window 254: start=37950, end=38250
# Window 255: start=38100, end=38400
# Window 256: start=38250, end=38550
# Window 257: start=38400, end=38700
# Window 258: start=38550, end=38850
# Window 259: start=38700, end=39000
# Window 260: start=38850, end=39150
# Window 261: start=39000, end=39300
# Window 262: start=39150, end=39450
# Window 263: start=39300, end=39600
# Window 264: start=39450, end=39750
# Window 265: start=39600, end=39900
# Window 266: start=39750, end=40050
# Window 267: start=39900, end=40200
# Window 268: start=40050, end=40350
# Window 269: start=40200, end=40500
# Window 270: start=40350, end=40650
# Window 271: start=40500, end=40800
# Window 272: start=40650, end=40950
# Window 273: start=40800, end=41100
# Window 274: start=40950, end=41250
# Window 275: start=41100, end=41400
# Window 276: start=41250, end=41550
# Window 277: start=41400, end=41700
# Window 278: start=41550, end=41850
# Window 279: start=41700, end=42000
# Window 280: start=41850, end=42150
# Window 281: start=42000, end=42300
# Window 282: start=42150, end=42450
# Window 283: start=42300, end=42600
# Window 284: start=42450, end=42750
# Window 285: start=42600, end=42900
# Window 286: start=42750, end=43050
# Window 287: start=42900, end=43200
# Window 288: start=43050, end=43350
# Window 289: start=43200, end=43500
# Window 290: start=43350, end=43650
# Window 291: start=43500, end=43800
# Window 292: start=43650, end=43950
# Window 293: start=43800, end=44100
# Window 294: start=43950, end=44250
# Window 295: start=44100, end=44400
# Window 296: start=44250, end=44550
# Window 297: start=44400, end=44700
# Window 298: start=44550, end=44850
# Window 299: start=44700, end=45000
# Window 300: start=44850, end=45150
# Window 301: start=45000, end=45300
# Window 302: start=45150, end=45450
# Window 303: start=45300, end=45600
# Window 304: start=45450, end=45750
# Window 305: start=45600, end=45900
# Window 306: start=45750, end=46050
# Window 307: start=45900, end=46200
# Window 308: start=46050, end=46350
# Window 309: start=46200, end=46500
# Window 310: start=46350, end=46650
# Window 311: start=46500, end=46800
# Window 312: start=46650, end=46950
# Window 313: start=46800, end=47100
# Window 314: start=46950, end=47250
# Window 315: start=47100, end=47400
# Window 316: start=47250, end=47550
# Window 317: start=47400, end=47700
# Window 318: start=47550, end=47850
# Window 319: start=47700, end=48000
# Window 320: start=47850, end=48150
# Window 321: start=48000, end=48300
# Window 322: start=48150, end=48450
# Window 323: start=48300, end=48600
# Window 324: start=48450, end=48750
# Window 325: start=48600, end=48900
# Window 326: start=48750, end=49050
# Window 327: start=48900, end=49200
# Window 328: start=49050, end=49350
# Window 329: start=49200, end=49500
# Window 330: start=49350, end=49650
# Window 331: start=49500, end=49800
# Window 332: start=49650, end=49950
# Window 333: start=49800, end=50100
# Window 334: start=49950, end=50250
# Window 335: start=50100, end=50400
# Window 336: start=50250, end=50550
# Window 337: start=50400, end=50700
# Window 338: start=50550, end=50850
# Window 339: start=50700, end=51000
# Window 340: start=50850, end=51150
# Window 341: start=51000, end=51300
# Window 342: start=51150, end=51450
# Window 343: start=51300, end=51600
# Window 344: start=51450, end=51750
# Window 345: start=51600, end=51900
# Window 346: start=51750, end=52050
# Window 347: start=51900, end=52200
# Window 348: start=52050, end=52350
# Window 349: start=52200, end=52500
# Window 350: start=52350, end=52650
# Window 351: start=52500, end=52800
# Window 352: start=52650, end=52950
# Window 353: start=52800, end=53100
# Window 354: start=52950, end=53250
# Window 355: start=53100, end=53400
# Window 356: start=53250, end=53550
# Window 357: start=53400, end=53700
# Window 358: start=53550, end=53850
# Window 359: start=53700, end=54000
# Window 360: start=53850, end=54150
# Window 361: start=54000, end=54300
# Window 362: start=54150, end=54450
# Window 363: start=54300, end=54600
# Window 364: start=54450, end=54750
# Window 365: start=54600, end=54900
# Window 366: start=54750, end=55050
# Window 367: start=54900, end=55200
# Window 368: start=55050, end=55350
# Window 369: start=55200, end=55500
# Window 370: start=55350, end=55650
# Window 371: start=55500, end=55800
# Window 372: start=55650, end=55950
# Window 373: start=55800, end=56100
# Window 374: start=55950, end=56250
# Window 375: start=56100, end=56400
# Window 376: start=56250, end=56550
# Window 377: start=56400, end=56700
# Window 378: start=56550, end=56850
# Window 379: start=56700, end=57000
# Window 380: start=56850, end=57150
# Window 381: start=57000, end=57300
# Window 382: start=57150, end=57450
# Window 383: start=57300, end=57600
# Window 384: start=57450, end=57750
# Window 385: start=57600, end=57900
# Window 386: start=57750, end=58050
# Window 387: start=57900, end=58200
# Window 388: start=58050, end=58350
# Window 389: start=58200, end=58500
# Window 390: start=58350, end=58650
# Window 391: start=58500, end=58800
# Window 392: start=58650, end=58950
# Window 393: start=58800, end=59100
# Window 394: start=58950, end=59250
# Window 395: start=59100, end=59400
# Window 396: start=59250, end=59550
# Window 397: start=59400, end=59700
# Window 398: start=59550, end=59850
# Window 399: start=59700, end=60000
# Window 400: start=59850, end=60150
# Window 401: start=60000, end=60300
# Window 402: start=60150, end=60450
# Window 403: start=60300, end=60600
# Window 404: start=60450, end=60750
# Window 405: start=60600, end=60900
# Window 406: start=60750, end=61050
# Window 407: start=60900, end=61200
# Window 408: start=61050, end=61350
# Window 409: start=61200, end=61500
# Window 410: start=61350, end=61650
# Window 411: start=61500, end=61800
# Window 412: start=61650, end=61950
# Window 413: start=61800, end=62100
# Window 414: start=61950, end=62250
# Window 415: start=62100, end=62400
# Window 416: start=62250, end=62550
# Window 417: start=62400, end=62700
# Window 418: start=62550, end=62850
# Window 419: start=62700, end=63000
# Window 420: start=62850, end=63150
# Window 421: start=63000, end=63300
# Window 422: start=63150, end=63450
# Window 423: start=63300, end=63600
# Window 424: start=63450, end=63750
# Window 425: start=63600, end=63900
# Window 426: start=63750, end=64050
# Window 427: start=63900, end=64200
# Window 428: start=64050, end=64350
# Window 429: start=64200, end=64500
# Window 430: start=64350, end=64650
# Window 431: start=64500, end=64800
# Window 432: start=64650, end=64950
# Window 433: start=64800, end=65100
# Window 434: start=64950, end=65250
# Window 435: start=65100, end=65400
# Window 436: start=65250, end=65550
# Window 437: start=65400, end=65700
# Window 438: start=65550, end=65850
# Window 439: start=65700, end=66000
# Window 440: start=65850, end=66150
# Window 441: start=66000, end=66300
# Window 442: start=66150, end=66450
# Window 443: start=66300, end=66600
# Window 444: start=66450, end=66750
# Window 445: start=66600, end=66900
# Window 446: start=66750, end=67050
# Window 447: start=66900, end=67200
# Window 448: start=67050, end=67350
# Window 449: start=67200, end=67500
# Window 450: start=67350, end=67650
# Window 451: start=67500, end=67800
# Window 452: start=67650, end=67950
# Window 453: start=67800, end=68100
# Window 454: start=67950, end=68250
# Window 455: start=68100, end=68400
# Window 456: start=68250, end=68550
# Window 457: start=68400, end=68700
# Window 458: start=68550, end=68850
# Window 459: start=68700, end=69000
# Window 460: start=68850, end=69150
# Window 461: start=69000, end=69300
# Window 462: start=69150, end=69450
# Window 463: start=69300, end=69600
# Window 464: start=69450, end=69750
# Window 465: start=69600, end=69900
# Window 466: start=69750, end=70050
# Window 467: start=69900, end=70200
# Window 468: start=70050, end=70350
# Window 469: start=70200, end=70500
# Window 470: start=70350, end=70650
# Window 471: start=70500, end=70800
# Window 472: start=70650, end=70950
# Window 473: start=70800, end=71100
# Window 474: start=70950, end=71250
# Window 475: start=71100, end=71400
# Window 476: start=71250, end=71550
# Window 477: start=71400, end=71700
# Window 478: start=71550, end=71850
# Window 479: start=71700, end=72000
# Window 480: start=71850, end=72150
# Window 481: start=72000, end=72300
# Window 482: start=72150, end=72450
# Window 483: start=72300, end=72600
# Window 484: start=72450, end=72750
# Window 485: start=72600, end=72900
# Window 486: start=72750, end=73050
# Window 487: start=72900, end=73200
# Window 488: start=73050, end=73350
# Window 489: start=73200, end=73500
# Window 490: start=73350, end=73650
# Window 491: start=73500, end=73800
# Window 492: start=73650, end=73950
# Window 493: start=73800, end=74100
# Window 494: start=73950, end=74250
# Window 495: start=74100, end=74400
# Window 496: start=74250, end=74550
# Window 497: start=74400, end=74700
# Window 498: start=74550, end=74850
# Window 499: start=74700, end=75000
# Window 500: start=74850, end=75150
# Window 501: start=75000, end=75300
# Window 502: start=75150, end=75450
# Window 503: start=75300, end=75600
# Window 504: start=75450, end=75750
# Window 505: start=75600, end=75900
# Window 506: start=75750, end=76050
# Window 507: start=75900, end=76200
# Window 508: start=76050, end=76350
# Window 509: start=76200, end=76500
# Window 510: start=76350, end=76650
# Window 511: start=76500, end=76800
# Window 512: start=76650, end=76950
# Window 513: start=76800, end=77100
# Window 514: start=76950, end=77250
# Window 515: start=77100, end=77400
# Window 516: start=77250, end=77550
# Window 517: start=77400, end=77700
# Window 518: start=77550, end=77850
# Window 519: start=77700, end=78000
# Window 520: start=77850, end=78150
# Window 521: start=78000, end=78300
# Window 522: start=78150, end=78450
# Window 523: start=78300, end=78600
# Window 524: start=78450, end=78750
# Window 525: start=78600, end=78900
# Window 526: start=78750, end=79050
# Window 527: start=78900, end=79200
# Window 528: start=79050, end=79350
# Window 529: start=79200, end=79500
# Window 530: start=79350, end=79650
# Window 531: start=79500, end=79800
# Window 532: start=79650, end=79950
# Window 533: start=79800, end=80100
# Window 534: start=79950, end=80250
# Window 535: start=80100, end=80400
# Window 536: start=80250, end=80550
# Window 537: start=80400, end=80700
# Window 538: start=80550, end=80850
# Window 539: start=80700, end=81000
# Window 540: start=80850, end=81150
# Window 541: start=81000, end=81300
# Window 542: start=81150, end=81450
# Window 543: start=81300, end=81600
# Window 544: start=81450, end=81750
# Window 545: start=81600, end=81900
# Window 546: start=81750, end=82050
# Window 547: start=81900, end=82200
# Window 548: start=82050, end=82350
# Window 549: start=82200, end=82500
# Window 550: start=82350, end=82650
# Window 551: start=82500, end=82800
# Window 552: start=82650, end=82950
# Window 553: start=82800, end=83100
# Window 554: start=82950, end=83250
# Window 555: start=83100, end=83400
# Window 556: start=83250, end=83550
# Window 557: start=83400, end=83700
# Window 558: start=83550, end=83850
# Window 559: start=83700, end=84000
# Window 560: start=83850, end=84150
# Window 561: start=84000, end=84300
# Window 562: start=84150, end=84450
# Window 563: start=84300, end=84600
# Window 564: start=84450, end=84750
# Window 565: start=84600, end=84900
# Window 566: start=84750, end=85050
# Window 567: start=84900, end=85200
# Window 568: start=85050, end=85350
# Window 569: start=85200, end=85500
# Window 570: start=85350, end=85650
# Window 571: start=85500, end=85800
# Window 572: start=85650, end=85950
# Window 573: start=85800, end=86100
# Window 574: start=85950, end=86250
# Window 575: start=86100, end=86400
# Window 576: start=86250, end=86550
# Window 577: start=86400, end=86700
# Window 578: start=86550, end=86850
# Window 579: start=86700, end=87000
# Window 580: start=86850, end=87150
# Window 581: start=87000, end=87300
# Window 582: start=87150, end=87450
# Window 583: start=87300, end=87600
# Window 584: start=87450, end=87750
# Window 585: start=87600, end=87900
# Window 586: start=87750, end=88050
# Window 587: start=87900, end=88200
# Window 588: start=88050, end=88350
# Window 589: start=88200, end=88500
# Window 590: start=88350, end=88650
# Window 591: start=88500, end=88800
# Window 592: start=88650, end=88950
# Window 593: start=88800, end=89100
# Window 594: start=88950, end=89250
# Window 595: start=89100, end=89400
# Window 596: start=89250, end=89550
# Window 597: start=89400, end=89700
# Window 598: start=89550, end=89850
# Window 599: start=89700, end=90000
# Window 600: start=89850, end=90150
# Window 601: start=90000, end=90300
# Window 602: start=90150, end=90450
# Window 603: start=90300, end=90600
# Window 604: start=90450, end=90750
# Window 605: start=90600, end=90900
# Window 606: start=90750, end=91050
# Window 607: start=90900, end=91200
# Window 608: start=91050, end=91350
# Window 609: start=91200, end=91500
# Window 610: start=91350, end=91650
# Window 611: start=91500, end=91800
# Window 612: start=91650, end=91950
# Window 613: start=91800, end=92100
# Window 614: start=91950, end=92250
# Window 615: start=92100, end=92400
# Window 616: start=92250, end=92550
# Window 617: start=92400, end=92700
# Window 618: start=92550, end=92850
# Window 619: start=92700, end=93000
# Window 620: start=92850, end=93150
# Window 621: start=93000, end=93300
# Window 622: start=93150, end=93450
# Window 623: start=93300, end=93600
# Window 624: start=93450, end=93750
# Window 625: start=93600, end=93900
# Window 626: start=93750, end=94050
# Window 627: start=93900, end=94200
# Window 628: start=94050, end=94350
# Window 629: start=94200, end=94500
# Window 630: start=94350, end=94650
# Window 631: start=94500, end=94800
# Window 632: start=94650, end=94950
# Window 633: start=94800, end=95100
# Window 634: start=94950, end=95250
# Window 635: start=95100, end=95400
# Window 636: start=95250, end=95550
# Window 637: start=95400, end=95700
# Window 638: start=95550, end=95850
# Window 639: start=95700, end=96000
# Window 640: start=95850, end=96150
# Window 641: start=96000, end=96300
# Window 642: start=96150, end=96450
# Window 643: start=96300, end=96600
# Window 644: start=96450, end=96750
# Window 645: start=96600, end=96900
# Window 646: start=96750, end=97050
# Window 647: start=96900, end=97200
# Window 648: start=97050, end=97350
# Window 649: start=97200, end=97500
# Window 650: start=97350, end=97650
# Window 651: start=97500, end=97800
# Window 652: start=97650, end=97950
# Window 653: start=97800, end=98100
# Window 654: start=97950, end=98250
# Window 655: start=98100, end=98400
# Window 656: start=98250, end=98550
# Window 657: start=98400, end=98700
# Window 658: start=98550, end=98850
# Window 659: start=98700, end=99000
# Window 660: start=98850, end=99150
# Window 661: start=99000, end=99300
# Window 662: start=99150, end=99450
# Window 663: start=99300, end=99600
# Window 664: start=99450, end=99750
# Window 665: start=99600, end=99900
# Window 666: start=99750, end=100050
# Window 667: start=99900, end=100200
# Window 668: start=100050, end=100350
# Window 669: start=100200, end=100500
# Window 670: start=100350, end=100650
# Window 671: start=100500, end=100800
# Window 672: start=100650, end=100950
# Window 673: start=100800, end=101100
# Window 674: start=100950, end=101250
# Window 675: start=101100, end=101400
# Window 676: start=101250, end=101550
# Window 677: start=101400, end=101700
# Window 678: start=101550, end=101850
# Window 679: start=101700, end=102000
# Window 680: start=101850, end=102150
# Window 681: start=102000, end=102300
# Window 682: start=102150, end=102450
# Window 683: start=102300, end=102600
# Window 684: start=102450, end=102750
# Window 685: start=102600, end=102900
# Window 686: start=102750, end=103050
# Window 687: start=102900, end=103200
# Window 688: start=103050, end=103350
# Window 689: start=103200, end=103500
# Window 690: start=103350, end=103650
# Window 691: start=103500, end=103800
# Window 692: start=103650, end=103950
# Window 693: start=103800, end=104100
# Window 694: start=103950, end=104250
# Window 695: start=104100, end=104400
# Window 696: start=104250, end=104550
# Window 697: start=104400, end=104700
# Window 698: start=104550, end=104850
# Window 699: start=104700, end=105000
# Window 700: start=104850, end=105150
# Window 701: start=105000, end=105300
# Window 702: start=105150, end=105450
# Window 703: start=105300, end=105600
# Window 704: start=105450, end=105750
# Window 705: start=105600, end=105900
# Window 706: start=105750, end=106050
# Window 707: start=105900, end=106200
# Window 708: start=106050, end=106350
# Window 709: start=106200, end=106500
# Window 710: start=106350, end=106650
# Window 711: start=106500, end=106800
# Window 712: start=106650, end=106950
# Window 713: start=106800, end=107100
# Window 714: start=106950, end=107250
# Window 715: start=107100, end=107400
# Window 716: start=107250, end=107550
# Window 717: start=107400, end=107700
# Window 718: start=107550, end=107850
# Window 719: start=107700, end=108000
# Window 720: start=107850, end=108150
# Window 721: start=108000, end=108300
# Window 722: start=108150, end=108450
# Window 723: start=108300, end=108600
# Window 724: start=108450, end=108750
# Window 725: start=108600, end=108900
# Window 726: start=108750, end=109050
# Window 727: start=108900, end=109200
# Window 728: start=109050, end=109350
# Window 729: start=109200, end=109500
# Window 730: start=109350, end=109650
# Window 731: start=109500, end=109800
# Window 732: start=109650, end=109950
# Window 733: start=109800, end=110100
# Window 734: start=109950, end=110250
# Window 735: start=110100, end=110400
# Window 736: start=110250, end=110550
# Window 737: start=110400, end=110700
# Window 738: start=110550, end=110850
# Window 739: start=110700, end=111000
# Window 740: start=110850, end=111150
# Window 741: start=111000, end=111300
# Window 742: start=111150, end=111450
# Window 743: start=111300, end=111600
# Window 744: start=111450, end=111750
# Window 745: start=111600, end=111900
# Window 746: start=111750, end=112050
# Window 747: start=111900, end=112200
# Window 748: start=112050, end=112350
# Window 749: start=112200, end=112500
# Window 750: start=112350, end=112650
# Window 751: start=112500, end=112800
# Window 752: start=112650, end=112950
# Window 753: start=112800, end=113100
# Window 754: start=112950, end=113250
# Window 755: start=113100, end=113400
# Window 756: start=113250, end=113550
# Window 757: start=113400, end=113700
# Window 758: start=113550, end=113850
# Window 759: start=113700, end=114000
# Window 760: start=113850, end=114150
# Window 761: start=114000, end=114300
# Window 762: start=114150, end=114450
# Window 763: start=114300, end=114600
# Window 764: start=114450, end=114750
# Window 765: start=114600, end=114900
# Window 766: start=114750, end=115050
# Window 767: start=114900, end=115200
# Window 768: start=115050, end=115350
# Window 769: start=115200, end=115500
# Window 770: start=115350, end=115650
# Window 771: start=115500, end=115800
# Window 772: start=115650, end=115950
# Window 773: start=115800, end=116100
# Window 774: start=115950, end=116250
# Window 775: start=116100, end=116400
# Window 776: start=116250, end=116550
# Window 777: start=116400, end=116700
# Window 778: start=116550, end=116850
# Window 779: start=116700, end=117000
# Window 780: start=116850, end=117150
# Window 781: start=117000, end=117300
# Window 782: start=117150, end=117450
# Window 783: start=117300, end=117600
# Window 784: start=117450, end=117750
# Window 785: start=117600, end=117900
# Window 786: start=117750, end=118050
# Window 787: start=117900, end=118200
# Window 788: start=118050, end=118350
# Window 789: start=118200, end=118500
# Window 790: start=118350, end=118650
# Window 791: start=118500, end=118800
# Window 792: start=118650, end=118950
# Window 793: start=118800, end=119100
# Window 794: start=118950, end=119250
# Window 795: start=119100, end=119400
# Window 796: start=119250, end=119550
# Window 797: start=119400, end=119700
# Window 798: start=119550, end=119850
# Window 799: start=119700, end=120000
# Window 800: start=119850, end=120150
# Window 801: start=120000, end=120300
# Window 802: start=120150, end=120450
# Window 803: start=120300, end=120600
# Window 804: start=120450, end=120750
# Window 805: start=120600, end=120900
# Window 806: start=120750, end=121050
# Window 807: start=120900, end=121200
# Window 808: start=121050, end=121350
# Window 809: start=121200, end=121500
# Window 810: start=121350, end=121650
# Window 811: start=121500, end=121800
# Window 812: start=121650, end=121950
# Window 813: start=121800, end=122100
# Window 814: start=121950, end=122250
# Window 815: start=122100, end=122400
# Window 816: start=122250, end=122550
# Window 817: start=122400, end=122700
# Window 818: start=122550, end=122850
# Window 819: start=122700, end=123000
# Window 820: start=122850, end=123150
# Window 821: start=123000, end=123300
# Window 822: start=123150, end=123450
# Window 823: start=123300, end=123600
# Window 824: start=123450, end=123750
# Window 825: start=123600, end=123900
# Window 826: start=123750, end=124050
# Window 827: start=123900, end=124200
# Window 828: start=124050, end=124350
# Window 829: start=124200, end=124500
# Window 830: start=124350, end=124650
# Window 831: start=124500, end=124800
# Window 832: start=124650, end=124950
# Window 833: start=124800, end=125100
# Window 834: start=124950, end=125250
# Window 835: start=125100, end=125400
# Window 836: start=125250, end=125550
# Window 837: start=125400, end=125700
# Window 838: start=125550, end=125850
# Window 839: start=125700, end=126000
# Window 840: start=125850, end=126150
# Window 841: start=126000, end=126300
# Window 842: start=126150, end=126450
# Window 843: start=126300, end=126600
# Window 844: start=126450, end=126750
# Window 845: start=126600, end=126900
# Window 846: start=126750, end=127050
# Window 847: start=126900, end=127200
# Window 848: start=127050, end=127350
# Window 849: start=127200, end=127500
# Window 850: start=127350, end=127650
# Window 851: start=127500, end=127800
# Window 852: start=127650, end=127950
# Window 853: start=127800, end=128100
# Window 854: start=127950, end=128250
# Window 855: start=128100, end=128400
# Window 856: start=128250, end=128550
# Window 857: start=128400, end=128700
# Window 858: start=128550, end=128850
# Window 859: start=128700, end=129000
# Window 860: start=128850, end=129150
# Window 861: start=129000, end=129300
# Window 862: start=129150, end=129450
# Window 863: start=129300, end=129600
# Window 864: start=129450, end=129750
# Window 865: start=129600, end=129900
# Window 866: start=129750, end=130050
# Window 867: start=129900, end=130200
# Window 868: start=130050, end=130350
# Window 869: start=130200, end=130500
# Window 870: start=130350, end=130650
# Window 871: start=130500, end=130800
# Window 872: start=130650, end=130950
# Window 873: start=130800, end=131100
# Window 874: start=130950, end=131250
# Window 875: start=131100, end=131400
# Window 876: start=131250, end=131550
# Window 877: start=131400, end=131700
# Window 878: start=131550, end=131850
# Window 879: start=131700, end=132000
# Window 880: start=131850, end=132150
# Window 881: start=132000, end=132300
# Window 882: start=132150, end=132450
# Window 883: start=132300, end=132600
# Window 884: start=132450, end=132750
# Window 885: start=132600, end=132900
# Window 886: start=132750, end=133050
# Window 887: start=132900, end=133200
# Window 888: start=133050, end=133350
# Window 889: start=133200, end=133500
# Window 890: start=133350, end=133650
# Window 891: start=133500, end=133800
# Window 892: start=133650, end=133950
# Window 893: start=133800, end=134100
# Window 894: start=133950, end=134250
# Window 895: start=134100, end=134400
# Window 896: start=134250, end=134550
# Window 897: start=134400, end=134700
# Window 898: start=134550, end=134850
# Window 899: start=134700, end=135000
# Window 900: start=134850, end=135150
# Window 901: start=135000, end=135300
# Window 902: start=135150, end=135450
# Window 903: start=135300, end=135600
# Window 904: start=135450, end=135750
# Window 905: start=135600, end=135900
# Window 906: start=135750, end=136050
# Window 907: start=135900, end=136200
# Window 908: start=136050, end=136350
# Window 909: start=136200, end=136500
# Window 910: start=136350, end=136650
# Window 911: start=136500, end=136800
# Window 912: start=136650, end=136950
# Window 913: start=136800, end=137100
# Window 914: start=136950, end=137250
# Window 915: start=137100, end=137400
# Window 916: start=137250, end=137550
# Window 917: start=137400, end=137700
# Window 918: start=137550, end=137850
# Window 919: start=137700, end=138000
# Window 920: start=137850, end=138150
# Window 921: start=138000, end=138300
# Window 922: start=138150, end=138450
# Window 923: start=138300, end=138600
# Window 924: start=138450, end=138750
# Window 925: start=138600, end=138900
# Window 926: start=138750, end=139050
# Window 927: start=138900, end=139200
# Window 928: start=139050, end=139350
# Window 929: start=139200, end=139500
# Window 930: start=139350, end=139650
# Window 931: start=139500, end=139800
# Window 932: start=139650, end=139950
# Window 933: start=139800, end=140100
# Window 934: start=139950, end=140250
# Window 935: start=140100, end=140400
# Window 936: start=140250, end=140550
# Window 937: start=140400, end=140700
# Window 938: start=140550, end=140850
# Window 939: start=140700, end=141000
# Window 940: start=140850, end=141150
# Window 941: start=141000, end=141300
# Window 942: start=141150, end=141450
# Window 943: start=141300, end=141600
# Window 944: start=141450, end=141750
# Window 945: start=141600, end=141900
# Window 946: start=141750, end=142050
# Window 947: start=141900, end=142200
# Window 948: start=142050, end=142350
# Window 949: start=142200, end=142500
# Window 950: start=142350, end=142650
# Window 951: start=142500, end=142800
# Window 952: start=142650, end=142950
# Window 953: start=142800, end=143100
# Window 954: start=142950, end=143250
# Window 955: start=143100, end=143400
# Window 956: start=143250, end=143550
# Window 957: start=143400, end=143700
# Window 958: start=143550, end=143850
# Window 959: start=143700, end=144000
# Window 960: start=143850, end=144150
# Window 961: start=144000, end=144300
# Window 962: start=144150, end=144450
# Window 963: start=144300, end=144600
# Window 964: start=144450, end=144750
# Window 965: start=144600, end=144900
# Window 966: start=144750, end=145050
# Window 967: start=144900, end=145200
# Window 968: start=145050, end=145350
# Window 969: start=145200, end=145500
# Window 970: start=145350, end=145650
# Window 971: start=145500, end=145800
# Window 972: start=145650, end=145950
# Window 973: start=145800, end=146100
# Window 974: start=145950, end=146250
# Window 975: start=146100, end=146400
# Window 976: start=146250, end=146550
# Window 977: start=146400, end=146700
# Window 978: start=146550, end=146850
# Window 979: start=146700, end=147000
# Window 980: start=146850, end=147150
# Window 981: start=147000, end=147300
# Window 982: start=147150, end=147450
# Window 983: start=147300, end=147600
# Window 984: start=147450, end=147750
# Window 985: start=147600, end=147900
# Window 986: start=147750, end=148050
# Window 987: start=147900, end=148200
# Window 988: start=148050, end=148350
# Window 989: start=148200, end=148500
# Window 990: start=148350, end=148650
# Window 991: start=148500, end=148800
# Window 992: start=148650, end=148950
# Window 993: start=148800, end=149100
# Window 994: start=148950, end=149250
# Window 995: start=149100, end=149400
# Window 996: start=149250, end=149550
# Window 997: start=149400, end=149700
# Window 998: start=149550, end=149850
# Window 999: start=149700, end=150000
# Window 1000: start=149850, end=150150
# Window 1001: start=150000, end=150300
# Window 1002: start=150150, end=150450
# Window 1003: start=150300, end=150600
# Window 1004: start=150450, end=150750
# Window 1005: start=150600, end=150900
# Window 1006: start=150750, end=151050
# Window 1007: start=150900, end=151200
# Window 1008: start=151050, end=151350
# Window 1009: start=151200, end=151500
# Window 1010: start=151350, end=151650
# Window 1011: start=151500, end=151800
# Window 1012: start=151650, end=151950
# Window 1013: start=151800, end=152100
# Window 1014: start=151950, end=152250
# Window 1015: start=152100, end=152400
# Window 1016: start=152250, end=152550
# Window 1017: start=152400, end=152700
# Window 1018: start=152550, end=152850
# Window 1019: start=152700, end=153000
# Window 1020: start=152850, end=153150
# Window 1021: start=153000, end=153300
# Window 1022: start=153150, end=153450
# Window 1023: start=153300, end=153600
# Window 1024: start=153450, end=153750
# Window 1025: start=153600, end=153900
# Window 1026: start=153750, end=154050
# Window 1027: start=153900, end=154200
# Window 1028: start=154050, end=154350
# Window 1029: start=154200, end=154500
# Window 1030: start=154350, end=154650
# Window 1031: start=154500, end=154800
# Window 1032: start=154650, end=154950
# Window 1033: start=154800, end=155100
# Window 1034: start=154950, end=155250
# Window 1035: start=155100, end=155400
# Window 1036: start=155250, end=155550
# Window 1037: start=155400, end=155700
# Window 1038: start=155550, end=155850
# Window 1039: start=155700, end=156000
# Window 1040: start=155850, end=156150
# Window 1041: start=156000, end=156300
# Window 1042: start=156150, end=156450
# Window 1043: start=156300, end=156600
# Window 1044: start=156450, end=156750
# Window 1045: start=156600, end=156900
# Window 1046: start=156750, end=157050
# Window 1047: start=156900, end=157200
# Window 1048: start=157050, end=157350
# Window 1049: start=157200, end=157500
# Window 1050: start=157350, end=157650
# Window 1051: start=157500, end=157800
# Window 1052: start=157650, end=157950
# Window 1053: start=157800, end=158100
# Window 1054: start=157950, end=158250
# Window 1055: start=158100, end=158400
# Window 1056: start=158250, end=158550
# Window 1057: start=158400, end=158700
# Window 1058: start=158550, end=158850
# Window 1059: start=158700, end=159000
# Window 1060: start=158850, end=159150
# Window 1061: start=159000, end=159300
# Window 1062: start=159150, end=159450
# Window 1063: start=159300, end=159600
# Window 1064: start=159450, end=159750
# Window 1065: start=159600, end=159900
# Window 1066: start=159750, end=160050
# Window 1067: start=159900, end=160200
# Window 1068: start=160050, end=160350
# Window 1069: start=160200, end=160500
# Window 1070: start=160350, end=160650
# Window 1071: start=160500, end=160800
# Window 1072: start=160650, end=160950
# Window 1073: start=160800, end=161100
# Window 1074: start=160950, end=161250
# Window 1075: start=161100, end=161400
# Window 1076: start=161250, end=161550
# Window 1077: start=161400, end=161700
# Window 1078: start=161550, end=161850
# Window 1079: start=161700, end=162000
# Window 1080: start=161850, end=162150
# Window 1081: start=162000, end=162300
# Window 1082: start=162150, end=162450
# Window 1083: start=162300, end=162600
# Window 1084: start=162450, end=162750
# Window 1085: start=162600, end=162900
# Window 1086: start=162750, end=163050
# Window 1087: start=162900, end=163200
# Window 1088: start=163050, end=163350
# Window 1089: start=163200, end=163500
# Window 1090: start=163350, end=163650
# Window 1091: start=163500, end=163800
# Window 1092: start=163650, end=163950
# Window 1093: start=163800, end=164100
# Window 1094: start=163950, end=164250
# Window 1095: start=164100, end=164400
# Window 1096: start=164250, end=164550
# Window 1097: start=164400, end=164700
# Window 1098: start=164550, end=164850
# Window 1099: start=164700, end=165000
# Window 1100: start=164850, end=165150
# Window 1101: start=165000, end=165300
# Window 1102: start=165150, end=165450
# Window 1103: start=165300, end=165600
# Window 1104: start=165450, end=165750
# Window 1105: start=165600, end=165900
# Window 1106: start=165750, end=166050
# Window 1107: start=165900, end=166200
# Window 1108: start=166050, end=166350
# Window 1109: start=166200, end=166500
# Window 1110: start=166350, end=166650
# Window 1111: start=166500, end=166800
# Window 1112: start=166650, end=166950
# Window 1113: start=166800, end=167100
# Window 1114: start=166950, end=167250
# Window 1115: start=167100, end=167400
# Window 1116: start=167250, end=167550
# Window 1117: start=167400, end=167700
# Window 1118: start=167550, end=167850
# Window 1119: start=167700, end=168000
# Window 1120: start=167850, end=168150
# Window 1121: start=168000, end=168300
# Window 1122: start=168150, end=168450
# Window 1123: start=168300, end=168600
# Window 1124: start=168450, end=168750
# Window 1125: start=168600, end=168900
# Window 1126: start=168750, end=169050
# Window 1127: start=168900, end=169200
# Window 1128: start=169050, end=169350
# Window 1129: start=169200, end=169500
# Window 1130: start=169350, end=169650
# Window 1131: start=169500, end=169800
# Window 1132: start=169650, end=169950
# Window 1133: start=169800, end=170100
# Window 1134: start=169950, end=170250
# Window 1135: start=170100, end=170400
# Window 1136: start=170250, end=170550
# Window 1137: start=170400, end=170700
# Window 1138: start=170550, end=170850
# Window 1139: start=170700, end=171000
# Window 1140: start=170850, end=171150
# Window 1141: start=171000, end=171300
# Window 1142: start=171150, end=171450
# Window 1143: start=171300, end=171600
# Window 1144: start=171450, end=171750
# Window 1145: start=171600, end=171900
# Window 1146: start=171750, end=172050
# Window 1147: start=171900, end=172200
# Window 1148: start=172050, end=172350
# Window 1149: start=172200, end=172500
# Window 1150: start=172350, end=172650
# Window 1151: start=172500, end=172800
# Window 1152: start=172650, end=172950
# Window 1153: start=172800, end=173100
# Window 1154: start=172950, end=173250
# Window 1155: start=173100, end=173400
# Window 1156: start=173250, end=173550
# Window 1157: start=173400, end=173700
# Window 1158: start=173550, end=173850
# Window 1159: start=173700, end=174000
# Window 1160: start=173850, end=174150
# Window 1161: start=174000, end=174300
# Window 1162: start=174150, end=174450
# Window 1163: start=174300, end=174600
# Window 1164: start=174450, end=174750
# Window 1165: start=174600, end=174900
# Window 1166: start=174750, end=175050
# Window 1167: start=174900, end=175200
# Window 1168: start=175050, end=175350
# Window 1169: start=175200, end=175500
# Window 1170: start=175350, end=175650
# Window 1171: start=175500, end=175800
# Window 1172: start=175650, end=175950
# Window 1173: start=175800, end=176100
# Window 1174: start=175950, end=176250
# Window 1175: start=176100, end=176400
# Window 1176: start=176250, end=176550
# Window 1177: start=176400, end=176700
# Window 1178: start=176550, end=176850
# Window 1179: start=176700, end=177000
# Window 1180: start=176850, end=177150
# Window 1181: start=177000, end=177300
# Window 1182: start=177150, end=177450
# Window 1183: start=177300, end=177600
# Window 1184: start=177450, end=177750
# Window 1185: start=177600, end=177900
# Window 1186: start=177750, end=178050
# Window 1187: start=177900, end=178200
# Window 1188: start=178050, end=178350
# Window 1189: start=178200, end=178500
# Window 1190: start=178350, end=178650
# Window 1191: start=178500, end=178800
# Window 1192: start=178650, end=178950
# Window 1193: start=178800, end=179100
# Window 1194: start=178950, end=179250
# Window 1195: start=179100, end=179400
# Window 1196: start=179250, end=179550
# Window 1197: start=179400, end=179700
# Window 1198: start=179550, end=179850
# Window 1199: start=179700, end=180000
# Window 1200: start=179850, end=180150
# Window 1201: start=180000, end=180300
# Window 1202: start=180150, end=180450
# Window 1203: start=180300, end=180600
# Window 1204: start=180450, end=180750
# Window 1205: start=180600, end=180900
# Window 1206: start=180750, end=181050
# Window 1207: start=180900, end=181200
# Window 1208: start=181050, end=181350
# Window 1209: start=181200, end=181500
# Window 1210: start=181350, end=181650
# Window 1211: start=181500, end=181800
# Window 1212: start=181650, end=181950
# Window 1213: start=181800, end=182100
# Window 1214: start=181950, end=182250
# Window 1215: start=182100, end=182400
# Window 1216: start=182250, end=182550
# Window 1217: start=182400, end=182700
# Window 1218: start=182550, end=182850
# Window 1219: start=182700, end=183000
# Window 1220: start=182850, end=183150
# Window 1221: start=183000, end=183300
# Window 1222: start=183150, end=183450
# Window 1223: start=183300, end=183600
# Window 1224: start=183450, end=183750
# Window 1225: start=183600, end=183900
# Window 1226: start=183750, end=184050
# Window 1227: start=183900, end=184200
# Window 1228: start=184050, end=184350
# Window 1229: start=184200, end=184500
# Window 1230: start=184350, end=184650
# Window 1231: start=184500, end=184800
# Window 1232: start=184650, end=184950
# Window 1233: start=184800, end=185100
# Window 1234: start=184950, end=185250
# Window 1235: start=185100, end=185400
# Window 1236: start=185250, end=185550
# Window 1237: start=185400, end=185700
# Window 1238: start=185550, end=185850
# Window 1239: start=185700, end=186000
# Window 1240: start=185850, end=186150
# Window 1241: start=186000, end=186300
# Window 1242: start=186150, end=186450
# Window 1243: start=186300, end=186600
# Window 1244: start=186450, end=186750
# Window 1245: start=186600, end=186900
# Window 1246: start=186750, end=187050
# Window 1247: start=186900, end=187200
# Window 1248: start=187050, end=187350
# Window 1249: start=187200, end=187500
# Window 1250: start=187350, end=187650
# Window 1251: start=187500, end=187800
# Window 1252: start=187650, end=187950
# Window 1253: start=187800, end=188100
# Window 1254: start=187950, end=188250
# Window 1255: start=188100, end=188400
# Window 1256: start=188250, end=188550
# Window 1257: start=188400, end=188700
# Window 1258: start=188550, end=188850
# Window 1259: start=188700, end=189000
# Window 1260: start=188850, end=189150
# Window 1261: start=189000, end=189300
# Window 1262: start=189150, end=189450
# Window 1263: start=189300, end=189600
# Window 1264: start=189450, end=189750
# Window 1265: start=189600, end=189900
# Window 1266: start=189750, end=190050
# Window 1267: start=189900, end=190200
# Window 1268: start=190050, end=190350
# Window 1269: start=190200, end=190500
# Window 1270: start=190350, end=190650
# Window 1271: start=190500, end=190800
# Window 1272: start=190650, end=190950
# Window 1273: start=190800, end=191100
# Window 1274: start=190950, end=191250
# Window 1275: start=191100, end=191400
# Window 1276: start=191250, end=191550
# Window 1277: start=191400, end=191700
# Window 1278: start=191550, end=191850
# Window 1279: start=191700, end=192000
# Window 1280: start=191850, end=192150
# Window 1281: start=192000, end=192300
# Window 1282: start=192150, end=192450
# Window 1283: start=192300, end=192600
# Window 1284: start=192450, end=192750
# Window 1285: start=192600, end=192900
# Window 1286: start=192750, end=193050
# Window 1287: start=192900, end=193200
# Window 1288: start=193050, end=193350
# Window 1289: start=193200, end=193500
# Window 1290: start=193350, end=193650
# Window 1291: start=193500, end=193800
# Window 1292: start=193650, end=193950
# Window 1293: start=193800, end=194100
# Window 1294: start=193950, end=194250
# Window 1295: start=194100, end=194400
# Window 1296: start=194250, end=194550
# Window 1297: start=194400, end=194700
# Window 1298: start=194550, end=194850
# Window 1299: start=194700, end=195000
# Window 1300: start=194850, end=195150
# Window 1301: start=195000, end=195300
# Window 1302: start=195150, end=195450
# Window 1303: start=195300, end=195600
# Window 1304: start=195450, end=195750
# Window 1305: start=195600, end=195900
# Window 1306: start=195750, end=196050
# Window 1307: start=195900, end=196200
# Window 1308: start=196050, end=196350
# Window 1309: start=196200, end=196500
# Window 1310: start=196350, end=196650
# Window 1311: start=196500, end=196800
# Window 1312: start=196650, end=196950
# Window 1313: start=196800, end=197100
# Window 1314: start=196950, end=197250
# Window 1315: start=197100, end=197400
# Window 1316: start=197250, end=197550
# Window 1317: start=197400, end=197700
# Window 1318: start=197550, end=197850
# Window 1319: start=197700, end=198000
# Window 1320: start=197850, end=198150
# Window 1321: start=198000, end=198300
# Window 1322: start=198150, end=198450
# Window 1323: start=198300, end=198600
# Window 1324: start=198450, end=198750
# Window 1325: start=198600, end=198900
# Window 1326: start=198750, end=199050
# Window 1327: start=198900, end=199200
# Window 1328: start=199050, end=199350
# Window 1329: start=199200, end=199500
# Window 1330: start=199350, end=199650
# Window 1331: start=199500, end=199800
# Window 1332: start=199650, end=199950
# Window 1333: start=199800, end=200100
# Window 1334: start=199950, end=200250
# Window 1335: start=200100, end=200400
# Window 1336: start=200250, end=200550
# Window 1337: start=200400, end=200700
# Window 1338: start=200550, end=200850
# Window 1339: start=200700, end=201000
# Window 1340: start=200850, end=201150
# Window 1341: start=201000, end=201300
# Window 1342: start=201150, end=201450
# Window 1343: start=201300, end=201600
# Window 1344: start=201450, end=201750
# Window 1345: start=201600, end=201900
# Window 1346: start=201750, end=202050
# Window 1347: start=201900, end=202200
# Window 1348: start=202050, end=202350
# Window 1349: start=202200, end=202500
# Window 1350: start=202350, end=202650
# Window 1351: start=202500, end=202800
# Window 1352: start=202650, end=202950
# Window 1353: start=202800, end=203100
# Window 1354: start=202950, end=203250
# Window 1355: start=203100, end=203400
# Window 1356: start=203250, end=203550
# Window 1357: start=203400, end=203700
# Window 1358: start=203550, end=203850
# Window 1359: start=203700, end=204000
# Window 1360: start=203850, end=204150
# Window 1361: start=204000, end=204300
# Window 1362: start=204150, end=204450
# Window 1363: start=204300, end=204600
# Window 1364: start=204450, end=204750
# Window 1365: start=204600, end=204900
# Window 1366: start=204750, end=205050
# Window 1367: start=204900, end=205200
# Window 1368: start=205050, end=205350
# Window 1369: start=205200, end=205500
# Window 1370: start=205350, end=205650
# Window 1371: start=205500, end=205800
# Window 1372: start=205650, end=205950
# Window 1373: start=205800, end=206100
# Window 1374: start=205950, end=206250
# Window 1375: start=206100, end=206400
# Window 1376: start=206250, end=206550
# Window 1377: start=206400, end=206700
# Window 1378: start=206550, end=206850
# Window 1379: start=206700, end=207000
# Window 1380: start=206850, end=207150
# Window 1381: start=207000, end=207300
# Window 1382: start=207150, end=207450
# Window 1383: start=207300, end=207600
# Window 1384: start=207450, end=207750
# Window 1385: start=207600, end=207900
# Window 1386: start=207750, end=208050
# Window 1387: start=207900, end=208200
# Window 1388: start=208050, end=208350
# Window 1389: start=208200, end=208500
# Window 1390: start=208350, end=208650
# Window 1391: start=208500, end=208800
# Window 1392: start=208650, end=208950
# Window 1393: start=208800, end=209100
# Window 1394: start=208950, end=209250
# Window 1395: start=209100, end=209400
# Window 1396: start=209250, end=209550
# Window 1397: start=209400, end=209700
# Window 1398: start=209550, end=209850
# Window 1399: start=209700, end=210000
# Window 1400: start=209850, end=210150
# Window 1401: start=210000, end=210300
# Window 1402: start=210150, end=210450
# Window 1403: start=210300, end=210600
# Window 1404: start=210450, end=210750
# Window 1405: start=210600, end=210900
# Window 1406: start=210750, end=211050
# Window 1407: start=210900, end=211200
# Window 1408: start=211050, end=211350
# Window 1409: start=211200, end=211500
# Window 1410: start=211350, end=211650
# Window 1411: start=211500, end=211800
# Window 1412: start=211650, end=211950
# Window 1413: start=211800, end=212100
# Window 1414: start=211950, end=212250
# Window 1415: start=212100, end=212400
# Window 1416: start=212250, end=212550
# Window 1417: start=212400, end=212700
# Window 1418: start=212550, end=212850
# Window 1419: start=212700, end=213000
# Window 1420: start=212850, end=213150
# Window 1421: start=213000, end=213300
# Window 1422: start=213150, end=213450
# Window 1423: start=213300, end=213600
# Window 1424: start=213450, end=213750
# Window 1425: start=213600, end=213900
# Window 1426: start=213750, end=214050
# Window 1427: start=213900, end=214200
# Window 1428: start=214050, end=214350
# Window 1429: start=214200, end=214500
# Window 1430: start=214350, end=214650
# Window 1431: start=214500, end=214800
# Window 1432: start=214650, end=214950
# Window 1433: start=214800, end=215100
# Window 1434: start=214950, end=215250
# Window 1435: start=215100, end=215400
# Window 1436: start=215250, end=215550
# Window 1437: start=215400, end=215700
# Window 1438: start=215550, end=215850
# Window 1439: start=215700, end=216000
# Window 1440: start=215850, end=216150
# Window 1441: start=216000, end=216300
# Window 1442: start=216150, end=216450
# Window 1443: start=216300, end=216600
# Window 1444: start=216450, end=216750
# Window 1445: start=216600, end=216900
# Window 1446: start=216750, end=217050
# Window 1447: start=216900, end=217200
# Window 1448: start=217050, end=217350
# Window 1449: start=217200, end=217500
# Window 1450: start=217350, end=217650
# Window 1451: start=217500, end=217800
# Window 1452: start=217650, end=217950
# Window 1453: start=217800, end=218100
# Window 1454: start=217950, end=218250
# Window 1455: start=218100, end=218400
# Window 1456: start=218250, end=218550
# Window 1457: start=218400, end=218700
# Window 1458: start=218550, end=218850
# Window 1459: start=218700, end=219000
# Window 1460: start=218850, end=219150
# Window 1461: start=219000, end=219300
# Window 1462: start=219150, end=219450
# Window 1463: start=219300, end=219600
# Window 1464: start=219450, end=219750
# Window 1465: start=219600, end=219900
# Window 1466: start=219750, end=220050
# Window 1467: start=219900, end=220200
# Window 1468: start=220050, end=220350
# Window 1469: start=220200, end=220500
# Window 1470: start=220350, end=220650
# Window 1471: start=220500, end=220800
# Window 1472: start=220650, end=220950
# Window 1473: start=220800, end=221100
# Window 1474: start=220950, end=221250
# Window 1475: start=221100, end=221400
# Window 1476: start=221250, end=221550
# Window 1477: start=221400, end=221700
# Window 1478: start=221550, end=221850
# Window 1479: start=221700, end=222000
# Window 1480: start=221850, end=222150
# Window 1481: start=222000, end=222300
# Window 1482: start=222150, end=222450
# Window 1483: start=222300, end=222600
# Window 1484: start=222450, end=222750
# Window 1485: start=222600, end=222900
# Window 1486: start=222750, end=223050
# Window 1487: start=222900, end=223200
# Window 1488: start=223050, end=223350
# Window 1489: start=223200, end=223500
# Window 1490: start=223350, end=223650
# Window 1491: start=223500, end=223800
# Window 1492: start=223650, end=223950
# Window 1493: start=223800, end=224100
# Window 1494: start=223950, end=224250
# Window 1495: start=224100, end=224400
# Window 1496: start=224250, end=224550
# Window 1497: start=224400, end=224700
# Window 1498: start=224550, end=224850
# Window 1499: start=224700, end=225000
# [[[ 6.07717455e-01  1.02360315e+00 -1.51095033e+00 -1.63192278e+00]
#   [ 1.09172456e+00  1.78303423e+00 -1.63608747e+00 -1.44243562e+00]
#   [ 1.48078188e+00  2.43278295e+00 -1.80472696e+00 -1.29755899e+00]
#   ...
#   [ 5.48065370e+00  1.01519174e+01  3.55722323e+00  7.04872332e+00]
#   [ 5.58034760e+00  9.97299448e+00  3.49551119e+00  6.88349776e+00]
#   [ 5.44943630e+00  9.42475862e+00  3.22012824e+00  6.43952265e+00]]
#
#  [[-5.27603102e-01 -7.85685807e+00 -2.25087483e+00  9.50004666e-01]
#   [-2.74219871e-01 -7.06021463e+00 -1.96339569e+00  1.55323069e+00]
#   [ 6.15768528e-02 -6.05837861e+00 -1.55073981e+00  2.23130888e+00]
#   ...
#   [ 1.11445725e+00 -1.14819839e+00  1.60892670e+00  3.47747206e+00]
#   [ 7.01600327e-01 -1.94549323e+00  1.00639837e+00  2.23089389e+00]
#   [ 4.39225551e-01 -2.56598416e+00  5.24100350e-01  1.07745540e+00]]
#
#  [[ 5.08863823e+00  8.52415075e+00  2.73383941e+00  5.73093681e+00]
#   [ 4.51689830e+00  7.31116432e+00  2.05661148e+00  4.78987343e+00]
#   [ 3.77016829e+00  5.84674941e+00  1.22445499e+00  3.66469444e+00]
#   ...
#   [ 6.66693735e-01  3.47974544e+00  2.25868627e+00  1.53742641e+00]
#   [ 8.90029411e-01  4.37089710e+00  2.74354168e+00  1.32300456e+00]
#   [ 8.85585366e-01  5.01799806e+00  3.04206180e+00  9.21268999e-01]]
#
#  ...
#
#  [[-3.47931665e+01 -2.72272623e+01 -3.81164715e+01 -1.93171057e+01]
#   [-2.95087321e+01 -2.23053777e+01 -3.36547463e+01 -1.47951194e+01]
#   [-2.36536629e+01 -1.69176836e+01 -2.89118742e+01 -9.68913846e+00]
#   ...
#   [-3.39634182e+01 -4.42230126e+01 -3.88458241e+01 -3.05084642e+01]
#   [-2.96910735e+01 -3.95488481e+01 -3.77059082e+01 -2.71680437e+01]
#   [-2.44499483e+01 -3.36457542e+01 -3.56445992e+01 -2.30440243e+01]]
#
#  [[-8.16784514e+01 -8.80680187e+01 -9.51172260e+01 -9.26256612e+01]
#   [-7.51720447e+01 -8.11261847e+01 -8.78166608e+01 -8.36463800e+01]
#   [-6.73724115e+01 -7.26839632e+01 -7.91604356e+01 -7.31920128e+01]
#   ...
#   [-1.31990466e+02 -1.41361178e+02 -1.34073057e+02 -1.63260886e+02]
#   [-1.38509054e+02 -1.44773505e+02 -1.36197181e+02 -1.63116676e+02]
#   [-1.43055128e+02 -1.46195185e+02 -1.36167210e+02 -1.60209118e+02]]
#
#  [[-1.85892462e+01 -2.68751337e+01 -3.29358099e+01 -1.84408718e+01]
#   [-1.25020358e+01 -1.96512740e+01 -2.98955889e+01 -1.37042138e+01]
#   [-6.59382598e+00 -1.24099975e+01 -2.68529683e+01 -9.19331511e+00]
#   ...
#   [ 5.47389039e+01  4.59763478e+01  5.24824406e+01  6.82397028e+01]
#   [ 5.23745385e+01  4.24479240e+01  5.05703151e+01  6.15491081e+01]
#   [ 4.96223514e+01  3.88136834e+01  4.84309763e+01  5.46323600e+01]]]

# %%
# Extract features from EMG data, windows' shape (num_windows x window_size x num_channels): (1151, 128, 256)
num_windows = windows.shape[0]
num_channels = windows.shape[2]
num_features = 14 # manual entry, might need to update it

feature_matrix = np.zeros((num_windows, num_channels, num_features))
print(feature_matrix.shape)

transposed_windows = windows.transpose(0,2,1)
print(transposed_windows.shape)
# Out:
# (1499, 4, 14)
# (1499, 4, 300)

# %%
# Iterate through each channel in each window, it takes some time to calculate longer than 2 mins
for window_index in range(num_windows):
    for channel_index in range(num_channels):
        channel_data = transposed_windows[window_index,channel_index,:]
        channel_features = extract_features(channel_data)
        feature_matrix[window_index, channel_index,:] = channel_features
        
print(feature_matrix.shape)  #feature matrix shape = num_windows (1151) x num_channels (256) x num_features(14)
# Out:
# (1499, 4, 14)

# %%
# Compute the feature correlation matrix with the python library pandas. Plot the correlation matrix and briefly mention which features you would use.

feature_names = ["MAV", "RMS", "Integral Absolute Value", "Variance", "Energy", "DASDV", "SSI", "Mean Power","Kurtosis","Skewness","Mean Frequency","Peak Frequency", "Waveform Length", "OHM"]

df = pd.DataFrame(np.mean(feature_matrix, axis=0), columns = feature_names) 

# Compute the correlation matrix, default pearson method is used here
correlation_matrix = df.corr() 

# Plot the correlation matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="PiYG", fmt=".2f", linewidths=.5)
plt.title("Feature Correlation Matrix using Pearson method")
plt.show()

# %%
# Remove highly correlated features, keep at least 5 features, if not increase the threshold slightly.
threshold = 0.95 # provided in the assignment
highly_correlated_features = set()

for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            colname = correlation_matrix.columns[i]
            highly_correlated_features.add(colname)

# Drop highly correlated features from the DataFrame
df_filtered = df.drop(columns=highly_correlated_features)

# Display the DataFrame after removing highly correlated features
#print("\nDataFrame after removing highly correlated features:")
#print(df_filtered)

# Compute the correlation matrix, default pearson method is used here
correlation_matrix_filtered = df_filtered.corr() 

# Plot the correlation matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_filtered, annot=True, cmap="PiYG", fmt=".2f", linewidths=.5)
plt.title("Feature Correlation Matrix using Pearson method Filtered")
plt.show()

print(highly_correlated_features)
# Out:
# {'Waveform Length', 'SSI', 'Mean Power', 'Energy', 'RMS', 'DASDV', 'Integral Absolute Value'}

# %%
feature_names = ["MAV", "RMS", "Integral Absolute Value", "Variance", "Energy", "DASDV", "SSI", "Mean Power", "Kurtosis", "Skewness", "Mean Frequency", "Peak Frequency", "Waveform Length", "OHM"]

# Features to delete
features_to_delete = ['Mean Power', 'Peak Frequency', 'Energy', 'SSI', 'RMS', 'Integral Absolute Value']

# Remove specified features
for feature in features_to_delete:
    if feature in feature_names:
        feature_names.remove(feature)

print("Updated feature_names:", feature_names)
# Out:
# Updated feature_names: ['MAV', 'Variance', 'DASDV', 'Kurtosis', 'Skewness', 'Mean Frequency', 'Waveform Length', 'OHM']

# %%
array_3d = feature_matrix

array_2d = array_3d.reshape(-1, array_3d.shape[-1])

columns = ["MAV", "RMS", "Integral Absolute Value", "Variance", "Energy", "DASDV", "SSI", "Mean Power","Kurtosis","Skewness","Mean Frequency","Peak Frequency", "Waveform Length", "OHM"]

df_ekin = pd.DataFrame(array_2d, columns=columns)

columns_to_drop = highly_correlated_features

df_dropped = df_ekin.drop(columns=columns_to_drop)

# Convert DataFrame back to NumPy array
array_after_drop = df_dropped.values.reshape(array_3d.shape[0], array_3d.shape[1], -1)

#print("Original 3D Array:")
#print(array_3d)

#print("\nDataFrame from 3D Array:")
#print(df_ekin)

#print("\nDataFrame after dropping columns:")
#print(df_dropped)

#print("\nNumPy array after dropping columns:")
#print(array_after_drop)

print("\nShape of feature matrix after dropping columns:")
print(array_after_drop.shape)
# Out:
# Shape of feature matrix after dropping columns:
# (1499, 4, 7)

# %%
# Define the length of the 1D array
length = 1499 #same as featue matrix 75 * 200 - 1

# Create a 1D array initialized with zeros
my_1d_array = np.zeros(length, dtype=int)

# Set the elements as specified
my_1d_array[:45 * 20] = 0
my_1d_array[45 * 20:50 * 20] = 1
my_1d_array[50 * 20:55 * 20] = 2
my_1d_array[55 * 20:60 * 20] = 3
my_1d_array[60 * 20:65 * 20] = 4
my_1d_array[65 * 20:70 * 20] = 5
my_1d_array[70 * 20:-1] = 6

# Print the resulting array
print(my_1d_array.shape)

labels = my_1d_array
# Out:
# (1499,)

# %%
print(emg_merged.shape)
# Print the resulting array
print(labels)
print(labels.shape)
# Out:
# (225000, 4)
# [0 0 0 ... 6 6 6]
# (225000,)

# %%
# Assuming X contains 7 features and y contains 7 labels.
X_3d = array_after_drop
y = labels
X = X_3d.reshape((X_3d.shape[0], -1))
print(X_3d.shape)
print(X.shape)
print(y.shape)
# Out:
# (1499, 4, 7)
# (1499, 28)
# (1499,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print(X_test.shape)
print(y_test.shape)
print(X_train.shape)
print(y_train.shape)
# Out:
# (450, 28)
# (450,)
# (1049, 28)
# (1049,)

# %%
from sklearn import svm

# X features, y labels

svm_classifier = svm.SVC(kernel='linear', decision_function_shape='ovr')  # OvR strategy

svm_classifier.fit(X_train, y_train)

predictions_svm = svm_classifier.predict(X_test)

accuracy_svm = accuracy_score(y_test, predictions_svm)
print("Accuracy:", accuracy_svm)
# Out:
# Accuracy: 0.8911111111111111

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda_classifier = LinearDiscriminantAnalysis()

lda_classifier.fit(X_train, y_train)

predictions_lda = lda_classifier.predict(X_test)

accuracy_lda = accuracy_score(y_test, predictions_lda)
print("Accuracy:", accuracy_lda)
# Out:
# Accuracy: 0.8755555555555555

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize 100 decision trees
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

rf_classifier.fit(X_train, y_train)

y_pred_rf = rf_classifier.predict(X_test)

accuracy_rf = accuracy_score(y_test, y_pred_rf)

print(f"Random Forest Classifier Accuracy: {accuracy_rf}")
# Out:
# Random Forest Classifier Accuracy: 0.9088888888888889
